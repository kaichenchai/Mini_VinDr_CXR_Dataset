# %%
from YOLOv8_Explainer import yolov8_heatmap, display_images

# %%
# !ls
import torch
model = torch.load("best.pt")
for param in model.parameters():
   param.requires_grad = True
# Out:
# Explainable-YOLOv8 explainer.ipynb    last.pt
# best.pt            images
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 4
#       2 import torch
#       3 model = torch.load("best.pt")
# ----> 4 for param in model.parameters():
#       5    param.requires_grad = True
#
# AttributeError: 'dict' object has no attribute 'parameters'

# %%
model = yolov8_heatmap(
    weight="last.pt", 
        conf_threshold=0.4, 
        method = "EigenCAM", 
        ratio=0.02,
        show_box=True,
        renormalize=False,
)
# Out:
# Model summary: 295 layers, 25,856,899 parameters, 0 gradients, 79.1 GFLOPs

# %%
imagelist = model(
    img_path="images/image.png",
    )

len(imagelist)
# Out:
# 1

# %%
display_images(imagelist)
